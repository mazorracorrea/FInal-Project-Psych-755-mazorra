# %% [markdown]
# **Classifier Polrization**
#
# **Final project**
#
# **Diego Mazorra**
#
# **Psych 757**

# %% [markdown]
# This notebook aims to build the polarization classifier. For this task, we are using data downloaded through the software Synthesio, authorized by the University of Wisconsin-Madison and the research group on Social Media and Democracy from the School of Journalism and Mass Communication of the same university.
# The data was compiled by selecting all the interactions in the social network Twitter (X) on the day of the political presidential debates for the elections in the USA in the year 2024. The first debate was between the candidates Joe Biden and Donald J. Trump. The second debate was between the candidates Kamala Harris and Donald J. Trump.
# The key terms of the search were: a) interactions (mentions and retweets); b) boolean marker Biden AND Trump AND Kamala AND Trump; c) search specific for the dates of the political debates, one for the first debate and the other for the second debate.
# The data cap limit for collection was 50,000 tweets retrieved. The list of tweets was then downloaded by selecting chunks of time where the total interactions were less than 50,000 and downloading in a .csv file the total interactions publicly available.
# The objective of this notebook is to produce a single dataset to work on this raw data and further anonymize the publicly available information.

# %% [markdown]
# **PART 1. - Create and clean the datasets**
#
#
# The objective of these first part of the code is to consolidate the raw data, clean it and produce an single dataset that is ready to our posterior analysys. Our raw data come for a different source in Synthesio, and clean it to process it will require several steps.
#
# **Structure:**
#
# Library: Imports libraries.
#
# Merge function: A function is defined to read all .csv files from a specified folder, handle potential errors common in Synthesio exports, and concatenate them into a single pandas DataFrame (merge_debate_csvs is the name of the function).
#
# Data: The merge_debate_csvs function is called for two separate folders—one for the Biden-Trump debate and one for the Harris-Trump debate. As a result we have 2 df, one ofr each debate.
#
# Debate identifier: A new column, Debate, is added to each dataset (with values 1 and 2) to distinguish between the two events before they are merged.
#
# Column selection and merge: A subset of relevant columns is selected from the raw data, and the two debate datasets are concatenated into one master DataFrame.
#
# Data cleaning with duplicate removal: Duplicate tweets are identified and removed based on their unique Id.
#
# Data cleaning with content removal: Tweets marked as "Deleted or protected mention" are filtered out as they contain no analyzable text.
#
# Text Sanitization: A sanitize_text function is defined using regular expressions (re) to clean the tweet text. This function converts text to lowercase, removes URLs and special characters, and standardizes whitespace. The output is stored in a new santext column.
#
# Sample: A random sample of 1000 tweets is drawn from the cleaned dataset to be used for annotation in the next phase of the project.

# %%
# Libraries required
import os
import pandas as pd
import glob
import re

# %%
#We need to create a function to create the datasets, 
# because there are too many and they are in the same folder as CSVs
#, merge will be the best, and merge all the folders, not by name, otherwise it will be demanding to classify every CSV file

def merge_debate_csvs(folder_path, output_filename):
    csv_files = glob.glob(os.path.join(folder_path, '*.csv'))
    dfs = []

    for file in csv_files:
        try:
            df = pd.read_csv(
                file,
                encoding='utf-8',
                sep=',',
                quotechar='"', #two separators "," and "" because synthesiso uses both in the raw files
                on_bad_lines='skip',  # skip rows that break parsing (this was one of the problems in the first versions of the code)
                engine='python'       
            )
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {file}: {e}") #in case we have pro0blmes with a file, we can identify the source

    if dfs:
        df_combined = pd.concat(dfs, ignore_index=True)
        os.makedirs('data/raw', exist_ok=True)
        df_combined.to_csv(f'data/raw/{output_filename}', index=False)
        print(f"Saved merged file: data/raw/{output_filename} — shape: {df_combined.shape}")
        return df_combined
    else:
        print(" No valid CSV files found.")
        return pd.DataFrame()

# %%
# Here we specify the location of the folders to run the previous function. 
#Also, we separate the folders to create 2 different files, one per debate.
folder_biden_trump = '/Users/diego/Downloads/USA/DEBATE BIDEN-TRUMP'
folder_kamala_trump = '/Users/diego/Downloads/USA/DEBATE KAMALA-TRUMP'

df_biden = merge_debate_csvs(folder_biden_trump, 'biden_trump_raw.csv')
df_kamala = merge_debate_csvs(folder_kamala_trump, 'kamala_trump_raw.csv')
# Out:
# Saved merged file: data/raw/biden_trump_raw.csv — shape: (1098310, 57)
# Saved merged file: data/raw/kamala_trump_raw.csv — shape: (2747862, 57)

# %%
#now, we have a data file, before advance, we don´t want surprises with the name of the columns, 
#so, before cleaning, we want to revise the strucutre and shape of the file and made a dictionary of variables

# Load the merged file (for Biden-Trump debate)
df_biden = pd.read_csv('data/raw/biden_trump_raw.csv', encoding='utf-8', engine='python')
print(df_biden.shape)
df_biden.head(3)  # Look at first 3 rows to visually inspect structure
# Out:
# (1098310, 57)
#              Id        Date                Time Media Type Site Name  \
# 0  281380390449  2024-06-27  22:30:00 -0500 CDT    Twitter   Twitter
# 1  281380353382  0000-12-31  18:09:24 -0550 LMT    Twitter   Twitter
# 2  281380386657  2024-06-27  22:30:00 -0500 CDT    Twitter   Twitter
#
#               Site Domain                                        Mention URL  \
# 0  http://www.twitter.com  http://twitter.com/LouisianaCRs/status/1806530...
# 1  http://www.twitter.com                       Deleted or protected mention
# 2  http://www.twitter.com  http://twitter.com/barneystoneage/status/18065...
#
#                               Publisher Name            Publisher Username  \
# 0              Louisiana College Republicans                  LouisianaCRs
# 1               Deleted or protected mention  Deleted or protected mention
# 2  “Deplorable” Barney “the Listless Vessel”                barneystoneage
#
#                                                title  ...  \
# 0  RT @cr_national: President Trump is the clear ...  ...
# 1                       Deleted or protected mention  ...
# 2  RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...  ...
#
#                Youtube Comments             Youtube Favorites  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#                        User Age                   User Gender  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#              User Family Status           User Marital Status  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#                 User Affinities                     User Jobs  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#             User biography tags                     Media URL
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
# [3 rows x 57 columns]

# %%
# Load the merged file (for Kamala-Trump debate)
df_kamala = pd.read_csv('data/raw/kamala_trump_raw.csv', encoding='utf-8', engine='python')
print(df_kamala.shape)
df_kamala.head(3)  # Look at first 3 rows to visually inspect structure
# Out:
# (2747862, 57)
#              Id        Date                Time Media Type Site Name  \
# 0  287695105673  2024-09-10  22:50:00 -0500 CDT    Twitter   Twitter
# 1  287695103227  2024-09-10  22:50:00 -0500 CDT    Twitter   Twitter
# 2  287695144422  2024-09-10  22:50:00 -0500 CDT    Twitter   Twitter
#
#               Site Domain                                        Mention URL  \
# 0  http://www.twitter.com  http://twitter.com/ced1951/status/183371463200...
# 1  http://www.twitter.com  http://twitter.com/MomInHerPJs/status/18337146...
# 2  http://www.twitter.com  http://twitter.com/carolynbunker9/status/18337...
#
#             Publisher Name Publisher Username  \
# 0            Charles Davis            ced1951
# 1            PamajaPants ?        MomInHerPJs
# 2  Old Lefty?️‍???????woke     carolynbunker9
#
#                                                title  ... Youtube Comments  \
# 0  RT @hodgetwins: Trump is right Virginias gover...  ...              NaN
# 1  RT @MrJonCryer: Hi Trump supporters I know rig...  ...              NaN
# 2  RT @MayoIsSpicyy: I want to see Kamala Harris ...  ...              NaN
#
#   Youtube Favorites User Age User Gender User Family Status  \
# 0               NaN      NaN         NaN                NaN
# 1               NaN      NaN         NaN                NaN
# 2               NaN      NaN         NaN                NaN
#
#   User Marital Status User Affinities User Jobs User biography tags  \
# 0                 NaN             NaN       NaN                 NaN
# 1                 NaN             NaN       NaN                 NaN
# 2                 NaN             NaN       NaN                 NaN
#
#                                            Media URL
# 0  https://pbs.twimg.com/ext_tw_video_thumb/10906...
# 1                                                NaN
# 2                                                NaN
#
# [3 rows x 57 columns]

# %%
# List the columns in each df
print("📌 Columns in Biden-Trump debate dataset:")
print(df_biden.columns.tolist())

print("\n📌 Columns in Kamala-Trump debate dataset:")
print(df_kamala.columns.tolist())
# Out:
# 📌 Columns in Biden-Trump debate dataset:
# ['Id', 'Date', 'Time', 'Media Type', 'Site Name', 'Site Domain', 'Mention URL', 'Publisher Name', 'Publisher Username', 'title', 'Mention Content', 'Topics', 'Subtopics', 'Classifiers', 'Classifiers tags', 'Review Products', 'Sentiment', 'Star Rating', 'Country', 'State', 'City', 'Language', 'Potential Reach', 'Engagement Rate', 'Interactions Total', 'Earned Media Value', 'Facebook Views', 'Facebook Likes', 'Facebook Comments', 'Facebook Shares', 'Facebook love reactions', 'Facebook haha reactions', 'Facebook wow reactions', 'Facebook sad reactions', 'Facebook angry reactions', 'Tiktok Likes', 'Tiktok Views', 'Tiktok Shares', 'Tiktok Comments', 'Twitter Retweets', 'Twitter Favorites', 'Twitter replies', 'Instagram Likes', 'Instagram Comments', 'Youtube Views', 'Youtube Likes', 'Youtube Dislikes', 'Youtube Comments', 'Youtube Favorites', 'User Age', 'User Gender', 'User Family Status', 'User Marital Status', 'User Affinities', 'User Jobs', 'User biography tags', 'Media URL']
#
# 📌 Columns in Kamala-Trump debate dataset:
# ['Id', 'Date', 'Time', 'Media Type', 'Site Name', 'Site Domain', 'Mention URL', 'Publisher Name', 'Publisher Username', 'title', 'Mention Content', 'Topics', 'Subtopics', 'Classifiers', 'Classifiers tags', 'Review Products', 'Sentiment', 'Star Rating', 'Country', 'State', 'City', 'Language', 'Potential Reach', 'Engagement Rate', 'Interactions Total', 'Earned Media Value', 'Facebook Views', 'Facebook Likes', 'Facebook Comments', 'Facebook Shares', 'Facebook love reactions', 'Facebook haha reactions', 'Facebook wow reactions', 'Facebook sad reactions', 'Facebook angry reactions', 'Tiktok Likes', 'Tiktok Views', 'Tiktok Shares', 'Tiktok Comments', 'Twitter Retweets', 'Twitter Favorites', 'Twitter replies', 'Instagram Likes', 'Instagram Comments', 'Youtube Views', 'Youtube Likes', 'Youtube Dislikes', 'Youtube Comments', 'Youtube Favorites', 'User Age', 'User Gender', 'User Family Status', 'User Marital Status', 'User Affinities', 'User Jobs', 'User biography tags', 'Media URL']

# %%
#Now, to avoid misinterpretation of each debate, we add a column to identify them
# Add Debate column: 1 for Biden-Trump, 2 for Kamala-Trump
df_biden['Debate'] = 1
df_kamala['Debate'] = 2

# Preview the result to verify that the columns were created with the nominal variables for each debate.
print(df_biden[['Id', 'Debate']].head(3))
print(df_kamala[['Id', 'Debate']].head(3))
# Out:
#              Id  Debate
# 0  281380390449       1
# 1  281380353382       1
# 2  281380386657       1
#              Id  Debate
# 0  287695105673       2
# 1  287695103227       2
# 2  287695144422       2

# %%
# Now we create a unique database with both debates
# Merge both df
df_all = pd.concat([df_biden, df_kamala], ignore_index=True)

# Save final combined file
df_all.to_csv('data/raw/debate_tweets_all_labeled.csv', index=False, encoding='utf-8')
print(f"Combined dataset saved. Shape: {df_all.shape}")
# Out:
# Combined dataset saved. Shape: (3846172, 58)

# %%
#now, the next step is to verify the shape and form of the file 
# Load the merged file
df_all = pd.read_csv('data/raw/debate_tweets_all_labeled.csv', encoding='utf-8', engine='python')
print(df_all.shape)
df_all.head(3)  # Look at first 3 rows to visually inspect structure
# Out:
# (3846172, 58)
#              Id        Date                Time Media Type Site Name  \
# 0  281380390449  2024-06-27  22:30:00 -0500 CDT    Twitter   Twitter
# 1  281380353382  0000-12-31  18:09:24 -0550 LMT    Twitter   Twitter
# 2  281380386657  2024-06-27  22:30:00 -0500 CDT    Twitter   Twitter
#
#               Site Domain                                        Mention URL  \
# 0  http://www.twitter.com  http://twitter.com/LouisianaCRs/status/1806530...
# 1  http://www.twitter.com                       Deleted or protected mention
# 2  http://www.twitter.com  http://twitter.com/barneystoneage/status/18065...
#
#                               Publisher Name            Publisher Username  \
# 0              Louisiana College Republicans                  LouisianaCRs
# 1               Deleted or protected mention  Deleted or protected mention
# 2  “Deplorable” Barney “the Listless Vessel”                barneystoneage
#
#                                                title  ...  \
# 0  RT @cr_national: President Trump is the clear ...  ...
# 1                       Deleted or protected mention  ...
# 2  RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...  ...
#
#               Youtube Favorites                      User Age  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#                     User Gender            User Family Status  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#             User Marital Status               User Affinities  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#                       User Jobs           User biography tags  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
#
#                       Media URL Debate
# 0                           NaN      1
# 1  Deleted or protected mention      1
# 2                           NaN      1
#
# [3 rows x 58 columns]

# %%
# now, we clean the data to anonymize and select the variables we are only going to require.
# Define the list of selected columns
selected_columns = [
    'Id', 'Date', 'Time', 'Media Type', 'Site Domain', 'Mention URL',
    'Publisher Name', 'Publisher Username', 'title', 'Mention Content',
    'Topics', 'Subtopics', 'Classifiers', 'Classifiers tags',
    'Sentiment', 'Potential Reach', 'Engagement Rate', 'Interactions Total',
    'Earned Media Value', 'Twitter Retweets', 'Twitter Favorites',
    'Twitter replies', 'Media URL', 'Debate'  
]

# Create the new filtered DataFrame
df_selected = df_all[selected_columns]

# Preview
print(df_selected.head())

# Save (the encoding file is needed because synthesio usually mess around with the encoding and programs like spss are sensible to that
df_selected.to_csv('data/raw/debate_tweets_selected.csv', index=False, encoding='utf-8')
print(f"Filtered dataset saved. Shape: {df_selected.shape}")
# Out:
#              Id        Date                Time Media Type  \
# 0  281380390449  2024-06-27  22:30:00 -0500 CDT    Twitter
# 1  281380353382  0000-12-31  18:09:24 -0550 LMT    Twitter
# 2  281380386657  2024-06-27  22:30:00 -0500 CDT    Twitter
# 3  281380349903  2024-06-27  22:30:00 -0500 CDT    Twitter
# 4  281380357944  2024-06-27  22:30:00 -0500 CDT    Twitter
#
#               Site Domain                                        Mention URL  \
# 0  http://www.twitter.com  http://twitter.com/LouisianaCRs/status/1806530...
# 1  http://www.twitter.com                       Deleted or protected mention
# 2  http://www.twitter.com  http://twitter.com/barneystoneage/status/18065...
# 3  http://www.twitter.com  http://twitter.com/unusual_doge/status/1806530...
# 4  http://www.twitter.com  http://twitter.com/KeepingUPosted/status/18065...
#
#                               Publisher Name            Publisher Username  \
# 0              Louisiana College Republicans                  LouisianaCRs
# 1               Deleted or protected mention  Deleted or protected mention
# 2  “Deplorable” Barney “the Listless Vessel”                barneystoneage
# 3                              (Golden) ᴅᴏɢᴇ                  unusual_doge
# 4                       Keeping You Posted ?                KeepingUPosted
#
#                                                title  \
# 0  RT @cr_national: President Trump is the clear ...
# 1                       Deleted or protected mention
# 2  RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...
# 3  RT @RpsAgainstTrump: Trump: “I didn't have sex...
# 4  RT @NickKnudsenUS: Whoa! Wonder why the North ...
#
#                                      Mention Content  ...  \
# 0  RT @cr_national: President Trump is the clear ...  ...
# 1                       Deleted or protected mention  ...
# 2  RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...  ...
# 3  RT @RpsAgainstTrump: Trump: “I didn't have sex...  ...
# 4  RT @NickKnudsenUS: Whoa! Wonder why the North ...  ...
#
#                       Sentiment               Potential Reach  \
# 0                      positive                           999
# 1  Deleted or protected mention  Deleted or protected mention
# 2                       neutral                          1592
# 3                       neutral                          2321
# 4                    unassigned                         11650
#
#                 Engagement Rate            Interactions Total  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#              Earned Media Value              Twitter Retweets  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#               Twitter Favorites               Twitter replies  \
# 0                           NaN                           NaN
# 1  Deleted or protected mention  Deleted or protected mention
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#                                            Media URL Debate
# 0                                                NaN      1
# 1                       Deleted or protected mention      1
# 2                                                NaN      1
# 3  https://pbs.twimg.com/amplify_video_thumb/1806...      1
# 4    https://pbs.twimg.com/media/GL81861XAAAzCkc.jpg      1
#
# [5 rows x 24 columns]
# Filtered dataset saved. Shape: (3846172, 24)

# %%
#Finally, we can clean the dataset. First, we need to find duplicate tweets, by found their ID Marker. 
#The way we collected the data can lead to have this problem fo duplicates
# Find duplicated Ids
duplicated_ids = df_selected[df_selected.duplicated(subset='Id', keep=False)]

# Count how many duplicates exist
num_duplicates = duplicated_ids['Id'].nunique()
print(f"Number of duplicated Ids: {num_duplicates}")
print(f"Total duplicated rows: {duplicated_ids.shape[0]}")

# View examples of duplicated
if num_duplicates > 0:
    # Show the Ids that are duplicated
    duplicate_id_list = duplicated_ids['Id'].unique()
    print(f"Sample duplicated Ids: {duplicate_id_list[:3]}")

    # For up to 3 duplicated Ids, show all associated rows
    for id_val in duplicate_id_list[:3]:
        print(f"\n Rows for duplicated Id: {id_val}")
        display(df_selected[df_selected['Id'] == id_val])
# Out:
# Number of duplicated Ids: 1118550
# Total duplicated rows: 2581706
# Sample duplicated Ids: [281380390449 281380353382 281380386657]
#
#  Rows for duplicated Id: 281380390449
#                   Id        Date                Time Media Type  \
# 0       281380390449  2024-06-27  22:30:00 -0500 CDT    Twitter
# 961523  281380390449  2024-06-27  22:30:00 -0500 CDT    Twitter
#
#                    Site Domain  \
# 0       http://www.twitter.com
# 961523  http://www.twitter.com
#
#                                               Mention URL  \
# 0       http://twitter.com/LouisianaCRs/status/1806530...
# 961523  http://twitter.com/LouisianaCRs/status/1806530...
#
#                        Publisher Name Publisher Username  \
# 0       Louisiana College Republicans       LouisianaCRs
# 961523  Louisiana College Republicans       LouisianaCRs
#
#                                                     title  \
# 0       RT @cr_national: President Trump is the clear ...
# 961523  RT @cr_national: President Trump is the clear ...
#
#                                           Mention Content  ... Sentiment  \
# 0       RT @cr_national: President Trump is the clear ...  ...  positive
# 961523  RT @cr_national: President Trump is the clear ...  ...  positive
#
#        Potential Reach Engagement Rate Interactions Total Earned Media Value  \
# 0                  999             NaN                NaN                NaN
# 961523             999             NaN                NaN                NaN
#
#        Twitter Retweets Twitter Favorites Twitter replies Media URL Debate
# 0                   NaN               NaN             NaN       NaN      1
# 961523              NaN               NaN             NaN       NaN      1
#
# [2 rows x 24 columns]
#  Rows for duplicated Id: 281380353382
#                   Id        Date                Time Media Type  \
# 1       281380353382  0000-12-31  18:09:24 -0550 LMT    Twitter
# 961526  281380353382  0000-12-31  18:09:24 -0550 LMT    Twitter
#
#                    Site Domain                   Mention URL  \
# 1       http://www.twitter.com  Deleted or protected mention
# 961526  http://www.twitter.com  Deleted or protected mention
#
#                       Publisher Name            Publisher Username  \
# 1       Deleted or protected mention  Deleted or protected mention
# 961526  Deleted or protected mention  Deleted or protected mention
#
#                                title               Mention Content  ...  \
# 1       Deleted or protected mention  Deleted or protected mention  ...
# 961526  Deleted or protected mention  Deleted or protected mention  ...
#
#                            Sentiment               Potential Reach  \
# 1       Deleted or protected mention  Deleted or protected mention
# 961526  Deleted or protected mention  Deleted or protected mention
#
#                      Engagement Rate            Interactions Total  \
# 1       Deleted or protected mention  Deleted or protected mention
# 961526  Deleted or protected mention  Deleted or protected mention
#
#                   Earned Media Value              Twitter Retweets  \
# 1       Deleted or protected mention  Deleted or protected mention
# 961526  Deleted or protected mention  Deleted or protected mention
#
#                    Twitter Favorites               Twitter replies  \
# 1       Deleted or protected mention  Deleted or protected mention
# 961526  Deleted or protected mention  Deleted or protected mention
#
#                            Media URL Debate
# 1       Deleted or protected mention      1
# 961526  Deleted or protected mention      1
#
# [2 rows x 24 columns]
#  Rows for duplicated Id: 281380386657
#                   Id        Date                Time Media Type  \
# 2       281380386657  2024-06-27  22:30:00 -0500 CDT    Twitter
# 961527  281380386657  2024-06-27  22:30:00 -0500 CDT    Twitter
#
#                    Site Domain  \
# 2       http://www.twitter.com
# 961527  http://www.twitter.com
#
#                                               Mention URL  \
# 2       http://twitter.com/barneystoneage/status/18065...
# 961527  http://twitter.com/barneystoneage/status/18065...
#
#                                    Publisher Name Publisher Username  \
# 2       “Deplorable” Barney “the Listless Vessel”     barneystoneage
# 961527  “Deplorable” Barney “the Listless Vessel”     barneystoneage
#
#                                                     title  \
# 2       RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...
# 961527  RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...
#
#                                           Mention Content  ... Sentiment  \
# 2       RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...  ...   neutral
# 961527  RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...  ...   neutral
#
#        Potential Reach Engagement Rate Interactions Total Earned Media Value  \
# 2                 1592             NaN                NaN                NaN
# 961527            1592             NaN                NaN                NaN
#
#        Twitter Retweets Twitter Favorites Twitter replies Media URL Debate
# 2                   NaN               NaN             NaN       NaN      1
# 961527              NaN               NaN             NaN       NaN      1
#
# [2 rows x 24 columns]

# %%
#There are too many duplicates, and we need to create a clean version
# The new data version transforms the selected dataset without duplicated Ids
df_unique = df_selected.drop_duplicates(subset='Id', keep='first').reset_index(drop=True)

# Save df
df_unique.to_csv('data/raw/debate_tweets_selected_unique.csv', index=False)

# Confirm result and print the summary to report later this in methods
print(f"Original rows: {df_selected.shape[0]}")
print(f"Rows after removing duplicates: {df_unique.shape[0]}")
# Out:
# Original rows: 3846172
# Rows after removing duplicates: 2383016

# %%
# Now, we have a lot of Deleted or protected mention form the source of the twitter itself, 
# Since it is impossible to analyze them, I will remove them from the db
# Count total tweets before filtering
total_before = df_unique.shape[0]

# Filter out rows with "Deleted or protected mention" in Mention Content
df_cleaned = df_unique[df_unique['Mention Content'] != "Deleted or protected mention"].copy()

# Count rows removed and rows remaining
total_removed = total_before - df_cleaned.shape[0]
total_after = df_cleaned.shape[0]

# Print summary to report these after in the methods section
print(f"Total tweets before cleaning: {total_before}")
print(f"Removed tweets with deleted/protected content: {total_removed}")
print(f"Final tweets after cleaning: {total_after}")

# check how many were removed
removed_count = df_unique.shape[0] - df_cleaned.shape[0]
print(f"Removed {removed_count} rows with deleted/protected content.")

# Save DF
df_cleaned.to_csv('data/raw/debate_tweets_selected_cleaned.csv', index=False)
print("Cleaned dataset saved as 'data/raw/debate_tweets_selected_cleaned.csv'")
# Out:
# Total tweets before cleaning: 2383016
# Removed tweets with deleted/protected content: 144304
# Final tweets after cleaning: 2238712
# Removed 144304 rows with deleted/protected content.
# Cleaned dataset saved as 'data/raw/debate_tweets_selected_cleaned.csv'

# %%
df_cleaned.head(50)
# Out:
#               Id        Date                Time Media Type  \
# 0   281380390449  2024-06-27  22:30:00 -0500 CDT    Twitter
# 2   281380386657  2024-06-27  22:30:00 -0500 CDT    Twitter
# 3   281380349903  2024-06-27  22:30:00 -0500 CDT    Twitter
# 4   281380357944  2024-06-27  22:30:00 -0500 CDT    Twitter
# 6   281380399438  2024-06-27  22:30:00 -0500 CDT    Twitter
# 7   281380375907  2024-06-27  22:30:00 -0500 CDT    Twitter
# 8   281380422012  2024-06-27  22:30:00 -0500 CDT    Twitter
# 9   281380409207  2024-06-27  22:30:00 -0500 CDT    Twitter
# 10  281380361576  2024-06-27  22:30:00 -0500 CDT    Twitter
# 11  281380369003  2024-06-27  22:30:00 -0500 CDT    Twitter
# 13  281380352552  2024-06-27  22:30:00 -0500 CDT    Twitter
# 14  281380406731  2024-06-27  22:30:00 -0500 CDT    Twitter
# 15  281380402830  2024-06-27  22:30:00 -0500 CDT    Twitter
# 16  281380362678  2024-06-27  22:30:00 -0500 CDT    Twitter
# 17  281380342682  2024-06-27  22:30:00 -0500 CDT    Twitter
# 19  281380425472  2024-06-27  22:30:00 -0500 CDT    Twitter
# 20  281380371839  2024-06-27  22:30:00 -0500 CDT    Twitter
# 21  281380415139  2024-06-27  22:30:00 -0500 CDT    Twitter
# 22  281380351080  2024-06-27  22:30:00 -0500 CDT    Twitter
# 23  281380382717  2024-06-27  22:30:00 -0500 CDT    Twitter
# 24  281380359678  2024-06-27  22:30:00 -0500 CDT    Twitter
# 25  281380390197  2024-06-27  22:30:00 -0500 CDT    Twitter
# 26  281380385638  2024-06-27  22:30:00 -0500 CDT    Twitter
# 27  281380363377  2024-06-27  22:30:00 -0500 CDT    Twitter
# 28  281380414384  2024-06-27  22:30:00 -0500 CDT    Twitter
# 29  281380403502  2024-06-27  22:30:00 -0500 CDT    Twitter
# 30  281380353181  2024-06-27  22:30:00 -0500 CDT    Twitter
# 31  281380406887  2024-06-27  22:30:00 -0500 CDT    Twitter
# 33  281380347434  2024-06-27  22:30:00 -0500 CDT    Twitter
# 34  281380356402  2024-06-27  22:30:00 -0500 CDT    Twitter
# 35  281380356416  2024-06-27  22:30:00 -0500 CDT    Twitter
# 36  281380393142  2024-06-27  22:30:00 -0500 CDT    Twitter
# 37  281380349623  2024-06-27  22:30:00 -0500 CDT    Twitter
# 38  281380409519  2024-06-27  22:30:00 -0500 CDT    Twitter
# 39  281380382787  2024-06-27  22:30:00 -0500 CDT    Twitter
# 40  281380359668  2024-06-27  22:30:00 -0500 CDT    Twitter
# 41  281380365718  2024-06-27  22:30:00 -0500 CDT    Twitter
# 42  281380365097  2024-06-27  22:30:00 -0500 CDT    Twitter
# 43  281380357672  2024-06-27  22:30:00 -0500 CDT    Twitter
# 44  281380368592  2024-06-27  22:30:00 -0500 CDT    Twitter
# 45  281380392950  2024-06-27  22:30:00 -0500 CDT    Twitter
# 46  281380356545  2024-06-27  22:30:00 -0500 CDT    Twitter
# 47  281380409833  2024-06-27  22:30:00 -0500 CDT    Twitter
# 48  281380404333  2024-06-27  22:30:00 -0500 CDT    Twitter
# 49  281380402098  2024-06-27  22:30:00 -0500 CDT    Twitter
# 50  281380367534  2024-06-27  22:30:00 -0500 CDT    Twitter
# 51  281380363163  2024-06-27  22:30:00 -0500 CDT    Twitter
# 52  281380416844  2024-06-27  22:30:00 -0500 CDT    Twitter
# 53  281380354404  2024-06-27  22:30:00 -0500 CDT    Twitter
# 54  281380359392  2024-06-27  22:30:00 -0500 CDT    Twitter
#
#                Site Domain                                        Mention URL  \
# 0   http://www.twitter.com  http://twitter.com/LouisianaCRs/status/1806530...
# 2   http://www.twitter.com  http://twitter.com/barneystoneage/status/18065...
# 3   http://www.twitter.com  http://twitter.com/unusual_doge/status/1806530...
# 4   http://www.twitter.com  http://twitter.com/KeepingUPosted/status/18065...
# 6   http://www.twitter.com  http://twitter.com/SteveKaye/status/1806530646...
# 7   http://www.twitter.com  http://twitter.com/OldToad99/status/1806530607...
# 8   http://www.twitter.com  http://twitter.com/gonzales_sid/status/1806530...
# 9   http://www.twitter.com  http://twitter.com/wuldntulik2kn/status/180653...
# 10  http://www.twitter.com  http://twitter.com/Tigerkenshin808/status/1806...
# 11  http://www.twitter.com  http://twitter.com/Mike19771/status/1806530575...
# 13  http://www.twitter.com  http://twitter.com/dave_m_/status/180653050117...
# 14  http://www.twitter.com  http://twitter.com/karenkmmonroy/status/180653...
# 15  http://www.twitter.com  http://twitter.com/KENNEDY______/status/180653...
# 16  http://www.twitter.com  http://twitter.com/Neaok11/status/180653055683...
# 17  http://www.twitter.com  http://twitter.com/Lewcas58/status/18065304651...
# 19  http://www.twitter.com  http://twitter.com/DfyGrvtAlwys/status/1806530...
# 20  http://www.twitter.com  http://twitter.com/jillayne/status/18065305996...
# 21  http://www.twitter.com  http://twitter.com/An3Fa_/status/1806530697508...
# 22  http://www.twitter.com  http://twitter.com/f_annunziata11/status/18065...
# 23  http://www.twitter.com  http://twitter.com/RiversLover94/status/180653...
# 24  http://www.twitter.com  http://twitter.com/NNA1022/status/180653051296...
# 25  http://www.twitter.com  http://twitter.com/sostfeldjohns/status/180653...
# 26  http://www.twitter.com  http://twitter.com/donbonaddio/status/18065306...
# 27  http://www.twitter.com  http://twitter.com/kimberlykmonday/status/1806...
# 28  http://www.twitter.com  http://twitter.com/T4booboo/status/18065307101...
# 29  http://www.twitter.com  http://twitter.com/MaYi40442936/status/1806530...
# 30  http://www.twitter.com  http://twitter.com/DerekDorman5/status/1806530...
# 31  http://www.twitter.com  http://twitter.com/pinkboots4ever/status/18065...
# 33  http://www.twitter.com  http://twitter.com/Darlene40954452/status/1806...
# 34  http://www.twitter.com  http://twitter.com/alexiajackson/status/180653...
# 35  http://www.twitter.com  http://twitter.com/BenVortex9000/status/180653...
# 36  http://www.twitter.com  http://twitter.com/PoohBabyEsq/status/18065306...
# 37  http://www.twitter.com  http://twitter.com/almostsingl1/status/1806530...
# 38  http://www.twitter.com  http://twitter.com/kikibean61/status/180653067...
# 39  http://www.twitter.com  http://twitter.com/KellenLPenn/status/18065305...
# 40  http://www.twitter.com  http://twitter.com/JohnnyArbo/status/180653052...
# 41  http://www.twitter.com  http://twitter.com/Itsasilvia/status/180653053...
# 42  http://www.twitter.com  http://twitter.com/MountainDreami2/status/1806...
# 43  http://www.twitter.com  http://twitter.com/BlankCode1923/status/180653...
# 44  http://www.twitter.com  http://twitter.com/FaithGrace7777/status/18065...
# 45  http://www.twitter.com  http://twitter.com/evansmp1/status/18065306480...
# 46  http://www.twitter.com  http://twitter.com/stefanie_decker/status/1806...
# 47  http://www.twitter.com  http://twitter.com/drSharonRabb/status/1806530...
# 48  http://www.twitter.com  http://twitter.com/TomGoodyear888/status/18065...
# 49  http://www.twitter.com  http://twitter.com/tykane08/status/18065306603...
# 50  http://www.twitter.com  http://twitter.com/AshmonkeyR94040/status/1806...
# 51  http://www.twitter.com  http://twitter.com/DitchdiggerBill/status/1806...
# 52  http://www.twitter.com  http://twitter.com/LarryWoods16/status/1806530...
# 53  http://www.twitter.com  http://twitter.com/Sanikri/status/180653050349...
# 54  http://www.twitter.com  http://twitter.com/dangainor/status/1806530527...
#
#                                        Publisher Name Publisher Username  \
# 0                       Louisiana College Republicans       LouisianaCRs
# 2           “Deplorable” Barney “the Listless Vessel”     barneystoneage
# 3                                       (Golden) ᴅᴏɢᴇ       unusual_doge
# 4                                Keeping You Posted ?     KeepingUPosted
# 6                                          Steve Kaye          SteveKaye
# 7                                   Old Toad (Parody)          OldToad99
# 8                                        Sid Gonzales       gonzales_sid
# 9                                       Wuldntulik2kn      wuldntulik2kn
# 10  "The Way is in training."~Miyamoto Musashi, Rob M    Tigerkenshin808
# 11                                        Mike Rindos          Mike19771
# 13                                            david m            dave_m_
# 14                      KarenMonroy Ph.D, Psy. ?? ?️?      karenkmmonroy
# 15                                                 KP      KENNEDY______
# 16                                         The#1Yoshi            Neaok11
# 17                                               Jane           Lewcas58
# 19                                          JM Schott       DfyGrvtAlwys
# 20                                  Jillayne Schlicke           jillayne
# 21                                              An3Fa             An3Fa_
# 22                                   Fabio Annunziata     f_annunziata11
# 23                           RiversCuomoLover1994Ever      RiversLover94
# 24                                             Nadine            NNA1022
# 25                                      Sharon OJ, MD      sostfeldjohns
# 26                                             Donnie        donbonaddio
# 27                                          Monday???    kimberlykmonday
# 28                                        Bart DeBear           T4booboo
# 29                                   Forever Trumper?       MaYi40442936
# 30                                            DD Boyz       DerekDorman5
# 31                                          PinkBoots     pinkboots4ever
# 33                                Darlene  Prosper TX    Darlene40954452
# 34                                             lexi ?      alexiajackson
# 35                                       Chaos Vortex      BenVortex9000
# 36                                         The Gemini        PoohBabyEsq
# 37                                      Almostsingl I       almostsingl1
# 38                                Kathryn L. Valencia         kikibean61
# 39                                             Kellen        KellenLPenn
# 40                                        Johnny Arbo         JohnnyArbo
# 41                                       Pearl/Silvie         Itsasilvia
# 42                                              Lissa    MountainDreami2
# 43                                      BlankCode ?‍?      BlankCode1923
# 44                         ATACMS W/O Restrictions ♥️     FaithGrace7777
# 45                                       Raider??????           evansmp1
# 46                                    Stefanie Decker    stefanie_decker
# 47                                              Rabia       drSharonRabb
# 48                                   ♛ Tom Goodyear ♛     TomGoodyear888
# 49                               tyson carness ? ? ??           tykane08
# 50                                AshmonkeyRoyale ??✞    AshmonkeyR94040
# 51                            Bill Miller ???????☸? ?    DitchdiggerBill
# 52                                        Larry Woods       LarryWoods16
# 53  Anna - Never give up. No matter what is going on!            Sanikri
# 54                                         Dan Gainor          dangainor
#
#                                                 title  \
# 0   RT @cr_national: President Trump is the clear ...
# 2   RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...
# 3   RT @RpsAgainstTrump: Trump: “I didn't have sex...
# 4   RT @NickKnudsenUS: Whoa! Wonder why the North ...
# 6   Share this. And then share this. And then Vote...
# 7   RT @MarinaMedvin: They didn’t just actively co...
# 8   RT @SpencerAlthouse: Biden just called out Tru...
# 9   RT @RpsAgainstTrump: Trump: “I didn't have sex...
# 10  RT @MarinaMedvin: They didn’t just actively co...
# 11  RT @RpsAgainstTrump: Trump: “I didn't have sex...
# 13  RT @What46HasDone: Joe Biden had a tough first...
# 14  RT @What46HasDone: Joe Biden had a tough first...
# 15  RT @BidensWins: BREAKING: Here is the clip whe...
# 16  RT @ayeejuju: Joe Biden bought up Trump having...
# 17  RT @washingtonpost: President Biden and former...
# 19  RT @AdamJSmithGA: An unhinged Trump second ter...
# 20  RT @hemantmehta: Biden is old but effective an...
# 21  RT @RealDLHughley: Every time #Trump is around...
# 22  RT @CollinRugg: JUST IN: President Biden admit...
# 23  RT @LyricVault: Donald Trump and Joe Biden sha...
# 24  RT @harryjsisson: HOLY CRAP! BIDEN JUST DESTRO...
# 25  RT @BidenHQ: NEW: We just launched our new web...
# 26  RT @RichardGrenell: . @kaitlancollins lied. Th...
# 27  RT @RichardGrenell: . @kaitlancollins lied. Th...
# 28  RT @harryjsisson: HOLY CRAP! BIDEN JUST DESTRO...
# 29  RT @ScottPresler: Noah Formica just registered...
# 30  RT @bennyjohnson: FLASHBACK: This is the video...
# 31  RT @cmclymer: I firmly believe President Biden...
# 33  RT @bennyjohnson: 🚨 BREAKING: Lara Trump REVEA...
# 34  RT @JessicaValenti: I'm sorry, but Trump just ...
# 35  RT @TheOnion: FACT CHECK Trump: “Biden is a ve...
# 36  RT @lexdanielle: I hate that people forget tha...
# 37  RT @ProjectLincoln: Tonight, Trump is trying t...
# 38  RT @JackPosobiec: Here is the clip of Ralph No...
# 39  RT @ErinInTheMorn: I know a lot of people who ...
# 40  RT @BehizyTweets: BREAKING: Trump's chances of...
# 41  RT @JoeBiden: Donald Trump is a convicted felo...
# 42  RT @gtlem: Surprise surprise - what did I tell...
# 43  🤡🤡🤡 RT @DschlopesIsBack: "Stupid bastards" - H...
# 44  RT @lisa_liberal: If you’re absolutely sick of...
# 45  RT @ScottPresler: To every black American, We ...
# 46  RT @MargoinWNC: Trump-“I offered 10k troops an...
# 47  RT @WarRoomShow: #WarRoomShow LIVE: CNN Making...
# 48  RT @JoeBiden: Donald Trump spent the night tal...
# 49  RT @mmpadellan: If trump is not going to answe...
# 50  RT @kayleighmcenany: Trump could have really l...
# 51  RT @BidenHQ: President Biden: No politician sh...
# 52  RT @ProjectLincoln: The difference between Pro...
# 53  RT @ddale8: Trump just did three false claims ...
# 54  RT @realKTMcFarland: Biggest consequence of de...
#
#                                       Mention Content  ...   Sentiment  \
# 0   RT @cr_national: President Trump is the clear ...  ...    positive
# 2   RT @BoLoudon: 🚨@MATTGAETZ, @RONNYJACKSONTX, & ...  ...     neutral
# 3   RT @RpsAgainstTrump: Trump: “I didn't have sex...  ...     neutral
# 4   RT @NickKnudsenUS: Whoa! Wonder why the North ...  ...  unassigned
# 6   Share this. And then share this. And then Vote...  ...  unassigned
# 7   RT @MarinaMedvin: They didn’t just actively co...  ...    negative
# 8   RT @SpencerAlthouse: Biden just called out Tru...  ...    negative
# 9   RT @RpsAgainstTrump: Trump: “I didn't have sex...  ...     neutral
# 10  RT @MarinaMedvin: They didn’t just actively co...  ...    negative
# 11  RT @RpsAgainstTrump: Trump: “I didn't have sex...  ...     neutral
# 13  RT @What46HasDone: Joe Biden had a tough first...  ...    negative
# 14  RT @What46HasDone: Joe Biden had a tough first...  ...    negative
# 15  RT @BidensWins: BREAKING: Here is the clip whe...  ...     neutral
# 16  RT @ayeejuju: Joe Biden bought up Trump having...  ...     neutral
# 17  RT @washingtonpost: President Biden and former...  ...     neutral
# 19  RT @AdamJSmithGA: An unhinged Trump second ter...  ...    negative
# 20  RT @hemantmehta: Biden is old but effective an...  ...  unassigned
# 21  RT @RealDLHughley: Every time #Trump is around...  ...    negative
# 22  RT @CollinRugg: JUST IN: President Biden admit...  ...     neutral
# 23  RT @LyricVault: Donald Trump and Joe Biden sha...  ...     neutral
# 24  RT @harryjsisson: HOLY CRAP! BIDEN JUST DESTRO...  ...    negative
# 25  RT @BidenHQ: NEW: We just launched our new web...  ...     neutral
# 26  RT @RichardGrenell: . @kaitlancollins lied. Th...  ...  unassigned
# 27  RT @RichardGrenell: . @kaitlancollins lied. Th...  ...  unassigned
# 28  RT @harryjsisson: HOLY CRAP! BIDEN JUST DESTRO...  ...    negative
# 29  RT @ScottPresler: Noah Formica just registered...  ...     neutral
# 30  RT @bennyjohnson: FLASHBACK: This is the video...  ...     neutral
# 31  RT @cmclymer: I firmly believe President Biden...  ...    negative
# 33  RT @bennyjohnson: 🚨 BREAKING: Lara Trump REVEA...  ...     neutral
# 34  RT @JessicaValenti: I'm sorry, but Trump just ...  ...     neutral
# 35  RT @TheOnion: FACT CHECK Trump: “Biden is a ve...  ...    negative
# 36  RT @lexdanielle: I hate that people forget tha...  ...    negative
# 37  RT @ProjectLincoln: Tonight, Trump is trying t...  ...     neutral
# 38  RT @JackPosobiec: Here is the clip of Ralph No...  ...    negative
# 39  RT @ErinInTheMorn: I know a lot of people who ...  ...    negative
# 40  RT @BehizyTweets: BREAKING: Trump's chances of...  ...     neutral
# 41  RT @JoeBiden: Donald Trump is a convicted felo...  ...    negative
# 42  RT @gtlem: Surprise surprise - what did I tell...  ...  unassigned
# 43  🤡🤡🤡 RT @DschlopesIsBack: "Stupid bastards" - H...  ...    negative
# 44  RT @lisa_liberal: If you’re absolutely sick of...  ...    negative
# 45  RT @ScottPresler: To every black American, We ...  ...  unassigned
# 46  RT @MargoinWNC: Trump-“I offered 10k troops an...  ...     neutral
# 47  RT @WarRoomShow: #WarRoomShow LIVE: CNN Making...  ...     neutral
# 48  RT @JoeBiden: Donald Trump spent the night tal...  ...     neutral
# 49  RT @mmpadellan: If trump is not going to answe...  ...    negative
# 50  RT @kayleighmcenany: Trump could have really l...  ...    negative
# 51  RT @BidenHQ: President Biden: No politician sh...  ...     neutral
# 52  RT @ProjectLincoln: The difference between Pro...  ...     neutral
# 53  RT @ddale8: Trump just did three false claims ...  ...    negative
# 54  RT @realKTMcFarland: Biggest consequence of de...  ...  unassigned
#
#    Potential Reach Engagement Rate Interactions Total Earned Media Value  \
# 0              999             NaN                NaN                NaN
# 2             1592             NaN                NaN                NaN
# 3             2321             NaN                NaN                NaN
# 4            11650             NaN                NaN                NaN
# 6              610             NaN                NaN                NaN
# 7              438             NaN                NaN                NaN
# 8             1831             NaN                NaN                NaN
# 9              682             NaN                NaN                NaN
# 10            1873             NaN                NaN                NaN
# 11            1328             NaN                NaN                NaN
# 13             359             NaN                NaN                NaN
# 14            2086             NaN                NaN                NaN
# 15            2505             NaN                NaN                NaN
# 16             343             NaN                NaN                NaN
# 17             709             NaN                NaN                NaN
# 19             557             NaN                NaN                NaN
# 20            1557             NaN                NaN                NaN
# 21              80             NaN                NaN                NaN
# 22             246             NaN                NaN                NaN
# 23             240             NaN                NaN                NaN
# 24              70             NaN                NaN                NaN
# 25            1006             NaN                NaN                NaN
# 26            2148             NaN                NaN                NaN
# 27            1217             NaN                NaN                NaN
# 28            1310             NaN                NaN                NaN
# 29            3601             NaN                NaN                NaN
# 30             210             NaN                NaN                NaN
# 31            2791             NaN                NaN                NaN
# 33           12996             NaN                NaN                NaN
# 34             252             NaN                NaN                NaN
# 35             129             NaN                NaN                NaN
# 36             248             NaN                NaN                NaN
# 37             709             NaN                NaN                NaN
# 38             542             NaN                NaN                NaN
# 39            2052             NaN                NaN                NaN
# 40             694             NaN                NaN                NaN
# 41             244             NaN                NaN                NaN
# 42            1218             NaN                NaN                NaN
# 43             507             NaN                NaN                NaN
# 44            7960             NaN                NaN                NaN
# 45           12637             NaN                NaN                NaN
# 46             988             NaN                NaN                NaN
# 47             808             NaN                NaN                NaN
# 48            1408             NaN                NaN                NaN
# 49             261             NaN                NaN                NaN
# 50            1901             NaN                NaN                NaN
# 51            8314             NaN                NaN                NaN
# 52             762             NaN                NaN                NaN
# 53            5677             NaN                NaN                NaN
# 54           24849             NaN                NaN                NaN
#
#    Twitter Retweets Twitter Favorites Twitter replies  \
# 0               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
# 6               NaN               NaN             NaN
# 7               NaN               NaN             NaN
# 8               NaN               NaN             NaN
# 9               NaN               NaN             NaN
# 10              NaN               NaN             NaN
# 11              NaN               NaN             NaN
# 13              NaN               NaN             NaN
# 14              NaN               NaN             NaN
# 15              NaN               NaN             NaN
# 16              NaN               NaN             NaN
# 17              NaN               NaN             NaN
# 19              NaN               NaN             NaN
# 20              NaN               NaN             NaN
# 21              NaN               NaN             NaN
# 22              NaN               NaN             NaN
# 23              NaN               NaN             NaN
# 24              NaN               NaN             NaN
# 25              NaN               NaN             NaN
# 26              NaN               NaN             NaN
# 27              NaN               NaN             NaN
# 28              NaN               NaN             NaN
# 29              NaN               NaN             NaN
# 30              NaN               NaN             NaN
# 31              NaN               NaN             NaN
# 33              NaN               NaN             NaN
# 34              NaN               NaN             NaN
# 35              NaN               NaN             NaN
# 36              NaN               NaN             NaN
# 37              NaN               NaN             NaN
# 38              NaN               NaN             NaN
# 39              NaN               NaN             NaN
# 40              NaN               NaN             NaN
# 41              NaN               NaN             NaN
# 42              NaN               NaN             NaN
# 43              NaN               NaN             NaN
# 44              NaN               NaN             NaN
# 45              NaN               NaN             NaN
# 46              NaN               NaN             NaN
# 47              NaN               NaN             NaN
# 48              NaN               NaN             NaN
# 49              NaN               NaN             NaN
# 50              NaN               NaN             NaN
# 51              NaN               NaN             NaN
# 52              NaN               NaN             NaN
# 53              NaN               NaN             NaN
# 54              NaN               NaN             NaN
#
#                                             Media URL Debate
# 0                                                 NaN      1
# 2                                                 NaN      1
# 3   https://pbs.twimg.com/amplify_video_thumb/1806...      1
# 4     https://pbs.twimg.com/media/GL81861XAAAzCkc.jpg      1
# 6     https://pbs.twimg.com/media/GEDaMOYWQAAbPxj.jpg      1
# 7                                                 NaN      1
# 8   https://pbs.twimg.com/ext_tw_video_thumb/18065...      1
# 9   https://pbs.twimg.com/amplify_video_thumb/1806...      1
# 10                                                NaN      1
# 11  https://pbs.twimg.com/amplify_video_thumb/1806...      1
# 13                                                NaN      1
# 14                                                NaN      1
# 15  https://pbs.twimg.com/ext_tw_video_thumb/17089...      1
# 16  https://pbs.twimg.com/ext_tw_video_thumb/12291...      1
# 17                                                NaN      1
# 19                                                NaN      1
# 20                                                NaN      1
# 21                                                NaN      1
# 22  https://pbs.twimg.com/amplify_video_thumb/1806...      1
# 23                                                NaN      1
# 24                                                NaN      1
# 25    https://pbs.twimg.com/media/GRFXMVBWYAIEXbB.jpg      1
# 26                                                NaN      1
# 27                                                NaN      1
# 28                                                NaN      1
# 29                                                NaN      1
# 30  https://pbs.twimg.com/amplify_video_thumb/1737...      1
# 31                                                NaN      1
# 33  https://pbs.twimg.com/amplify_video_thumb/1806...      1
# 34                                                NaN      1
# 35                                                NaN      1
# 36                                                NaN      1
# 37  https://pbs.twimg.com/ext_tw_video_thumb/18065...      1
# 38  https://pbs.twimg.com/ext_tw_video_thumb/11225...      1
# 39                                                NaN      1
# 40                                                NaN      1
# 41                                                NaN      1
# 42                                                NaN      1
# 43  https://pbs.twimg.com/amplify_video_thumb/1806...      1
# 44                                                NaN      1
# 45                                                NaN      1
# 46                                                NaN      1
# 47                                                NaN      1
# 48                                                NaN      1
# 49                                                NaN      1
# 50                                                NaN      1
# 51    https://pbs.twimg.com/media/GRIKEKPbwAABagA.jpg      1
# 52    https://pbs.twimg.com/media/GNA2CJ_WwAA5OVx.jpg      1
# 53                                                NaN      1
# 54                                                NaN      1
#
# [50 rows x 24 columns]

# %%
#now create a sanitized text column (the reason we charge the library re)
# for info of the library is: (and the first edition cover examples of use)
#Friedl, Jeffrey. Mastering Regular Expressions. 3rd ed., O'Reilly Media, 2009.

# Function to sanitize text: lowercasing, remove URLs, special characters, and extra whitespace
def sanitize_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"http\S+|www.\S+", "", text)           # remove URLs
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)            # remove special characters
    text = re.sub(r"\s+", " ", text).strip()              # remove extra whitespace
    return text

# Apply to 'title' and store in new column 'santext'
df_cleaned['santext'] = df_cleaned['title'].apply(sanitize_text)

# preview 
print(df_cleaned[['title', 'santext']].sample(5))

# Save with sanitized text
df_cleaned.to_csv('data/raw/debate_tweets_selected_cleaned_with_santext.csv', index=False)
print("Cleaned dataset with 'santext' saved to 'data/raw/debate_tweets_selected_cleaned_with_santext.csv'")
# Out:
#                                                      title  \
# 949317   RT @RobertKennedyJr: VP Harris sounds like she...
# 7547     RT @BPUnion: To be clear, we never have and ne...
# 730646   This was reminiscent of when that lady called ...
# 1076511  The swifities?? Yeah Trump is finished RT @Pop...
# 147600   RT @reproforall: Donald Trump fact check: The ...
#
#                                                    santext
# 949317   rt robertkennedyjr vp harris sounds like she j...
# 7547     rt bpunion to be clear we never have and never...
# 730646   this was reminiscent of when that lady called ...
# 1076511  the swifities yeah trump is finished rt popbas...
# 147600   rt reproforall donald trump fact check the vas...
# Cleaned dataset with 'santext' saved to 'data/raw/debate_tweets_selected_cleaned_with_santext.csv'

# %%
# Now create the sample code to compare. We can use hand coders, 
#but since this is a project of only one person, we are trying to do a different apporach
# Let's try to use ChatGPT as a coder for the first sample.
# Set seed for reproducibility
# Load cleaned and sanitized data
df_sanitized = pd.read_csv('data/raw/debate_tweets_selected_cleaned_with_santext.csv')

# Create sample from it
sample_df = df_sanitized.sample(n=1000, random_state=42).copy()

# Reset index for clarity
sample_df.reset_index(drop=True, inplace=True)

# Save the sample
os.makedirs('data/sample', exist_ok=True)
sample_df.to_csv('data/sample/debate_tweets_sample_1000.csv', index=False)
print(" Sample saved: data/sample/debate_tweets_sample_1000.csv")
# We have a warning due to the mixed type of data in the columns.
# Out:
# /var/folders/8x/qy8j1cyj36jd9vpnlk90r0hh0000gn/T/ipykernel_25442/3100714635.py:6: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sanitized = pd.read_csv('data/raw/debate_tweets_selected_cleaned_with_santext.csv')
#  Sample saved: data/sample/debate_tweets_sample_1000.csv

# %%
#now, this step if we choose doing a hand code process...let's prepare the file and add some columns for the polarization measures we want to try
# Load the sample dataset
# df_sample2 = pd.read_csv('data/sample/debate_tweets_sample_1000.csv')

# Add columns for manual polarization coding
# df_sample2['polar_score'] = ""       # To be filled with -7 to 7 or 'INV'
# df_sample2['pole_label'] = ""        # 'left', 'right', 'neutral', or 'inv'
# df_sample2['valid'] = ""             # 1 for valid, 0 for invalid
# df_sample2['comments'] = ""          # Optional comments field

# Save updated file
# df_sample2.to_csv('data/sample/debate_tweets_sample_1000_for_annotation.csv', index=False)
# print("File saved with annotation columns.")
